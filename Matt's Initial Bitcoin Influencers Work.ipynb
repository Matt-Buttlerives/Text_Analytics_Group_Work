# %%
#### INSY 669 GROUP PROJECT ####
#### Matt's Code analysis for different time periods and different influencers
#### For this code book, bitcoin only

# %%
# Importing Packages
import snscrape.modules.twitter as sntwitter
import pandas as pd
import string

# nltk packages
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

# Vader Package
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
### MMCrypto, bitcoin and ethereum price forecastor ###

# %%
key_word = "bitcoin" # Define Key Word
user_name = "MMCrypto" # 8th most followed bitcoin account on Twitter
from_date = "2021-01-01" # Different start date due to lack of tweets
end_date = "2021-04-01" # Different end date due to lack of tweets
count = 10000 
tweets_list_keyword = []
tweets_list_user = []

# %%
#### Scraping tweets a specific Twitter user’s account (MMCrypto) ####
command_user = key_word+' from:'+user_name+' since:'+from_date+' until:'+end_date
print("Scraping data for user:",key_word,user_name)
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(command_user).get_items()): 
    tweets_list_user.append([tweet.date,tweet.id, tweet.content, tweet.user.username, tweet.url]) 
    if i > count:
        break;
# Create a dataframe from the tweets list above 
tweets_df_user = pd.DataFrame(tweets_list_user, columns=['Datetime','Tweet Id', 'Text', 'Username', 'url'])
tweets_df_user.to_csv("MMCrypto_Bitcoin_tweets_users.csv",index=False) # Export to a csv file
print("Scraped data have been exported to the csv file")
# Out:
# Scraping data for user: bitcoin MMCrypto
# Scraped data have been exported to the csv file

# %%
##### Looking into Vitalik Buterin - Ethereum Co-founder 1.9 million followers #####

# %%
#key_word = "Ethereum" # Define Key Word
#user_name = "vitalik.eth" # 8th most followed bitcoin account on Twitter
#from_date = "2021-10-28" # Atrin's start date
#end_date = "2021-11-08" # Atrin's end date
#count = 10000 
#tweets_list_keyword = []
#tweets_list_user = []

# %%
#### Scraping tweets a specific Twitter user’s account 
#command_user = key_word+' from:'+user_name+' since:'+from_date+' until:'+end_date
#print("Scraping data for user:",key_word,user_name)
#for i,tweet in enumerate(sntwitter.TwitterSearchScraper(command_user).get_items()): 
#    tweets_list_user.append([tweet.date,tweet.id, tweet.content, tweet.user.username, tweet.url]) 
 #   if i > count:
 #       break;
# Create a dataframe from the tweets list above 
#tweets_df_user = pd.DataFrame(tweets_list_user, columns=['Datetime','Tweet Id', 'Text', 'Username', 'url'])
#tweets_df_user.to_csv("ethereum_tweets_users.csv",index=False) # Export to a csv file
#print("Scraped data have been exported to the csv file")

# %%
##### Roger Ver - Bitcoin Promoter - 720,000 followers #####

# %%
key_word = "bitcoin" # Define Key Word
user_name = "@rogerkver" # 8th most followed bitcoin account on Twitter
from_date = "2021-01-01" # Different start date due to lack of tweets
end_date = "2021-04-01" # Different end date due to lack of tweets
count = 10000 
tweets_list_keyword = []
tweets_list_user = []

# %%
#### Scraping tweets a specific Twitter user’s account
command_user = key_word+' from:'+user_name+' since:'+from_date+' until:'+end_date
print("Scraping data for user:",key_word,user_name)
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(command_user).get_items()): 
    tweets_list_user.append([tweet.date,tweet.id, tweet.content, tweet.user.username, tweet.url]) 
    if i > count:
        break;
# Create a dataframe from the tweets list above 
tweets_df_user = pd.DataFrame(tweets_list_user, columns=['Datetime','Tweet Id', 'Text', 'Username', 'url'])
tweets_df_user.to_csv("Roger_Ver_bitcoin_only_tweets_users.csv",index=False) # Export to a csv file
print("Scraped data have been exported to the csv file")
# Out:
# Scraping data for user: bitcoin @rogerkver
# Scraped data have been exported to the csv file

# %%
##### Andreas M.Antonopoulos - Bitcoin Advocate - 600,000 followers ####

# %%
key_word = "bitcoin" # Define Key Word
user_name = "@aantonop" # 8th most followed bitcoin account on Twitter
from_date = "2021-01-01" # Different start date due to lack of tweets
end_date = "2021-04-01" # Different end date due to lack of tweets
count = 10000 
tweets_list_keyword = []
tweets_list_user = []

# %%
#### Scraping tweets a specific Twitter user’s account
command_user = key_word+' from:'+user_name+' since:'+from_date+' until:'+end_date
print("Scraping data for user:",key_word,user_name)
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(command_user).get_items()): 
    tweets_list_user.append([tweet.date,tweet.id, tweet.content, tweet.user.username, tweet.url]) 
    if i > count:
        break;
# Create a dataframe from the tweets list above 
tweets_df_user = pd.DataFrame(tweets_list_user, columns=['Datetime','Tweet Id', 'Text', 'Username', 'url'])
tweets_df_user.to_csv("Aantop_bitcoin_only_tweets_users.csv",index=False) # Export to a csv file
print("Scraped data have been exported to the csv file")
# Out:
# Scraping data for user: bitcoin @aantonop
# Scraped data have been exported to the csv file

# %%
##### Tim Draper - Bitcoin Price Forecaster - 200,000 followers ####

# %%
key_word = "bitcoin" # Define Key Word
user_name = "@TimDraper" # 8th most followed bitcoin account on Twitter
from_date = "2021-01-01" # Different start date due to lack of tweets
end_date = "2021-04-01" # Different end date due to lack of tweets
count = 10000 
tweets_list_keyword = []
tweets_list_user = []

# %%
#### Scraping tweets a specific Twitter user’s account
command_user = key_word+' from:'+user_name+' since:'+from_date+' until:'+end_date
print("Scraping data for user:",key_word,user_name)
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(command_user).get_items()): 
    tweets_list_user.append([tweet.date,tweet.id, tweet.content, tweet.user.username, tweet.url]) 
    if i > count:
        break;
# Create a dataframe from the tweets list above 
tweets_df_user = pd.DataFrame(tweets_list_user, columns=['Datetime','Tweet Id', 'Text', 'Username', 'url'])
tweets_df_user.to_csv("TimDraper_bitcoin_only_tweets_users.csv",index=False) # Export to a csv file
print("Scraped data have been exported to the csv file")
# Out:
# Scraping data for user: bitcoin @TimDraper
# Scraped data have been exported to the csv file

# %%
##### Anthony Pompliano - Pioneer Bitcoin Supporter - 1,000,000 followers ####

# %%
key_word = "bitcoin" # Define Key Word
user_name = "@APompliano" # 8th most followed bitcoin account on Twitter
from_date = "2021-01-01" # Different start date due to lack of tweets
end_date = "2021-04-01" # Different end date due to lack of tweets
count = 10000 
tweets_list_keyword = []
tweets_list_user = []

# %%
#### Scraping tweets a specific Twitter user’s account
command_user = key_word+' from:'+user_name+' since:'+from_date+' until:'+end_date
print("Scraping data for user:",key_word,user_name)
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(command_user).get_items()): 
    tweets_list_user.append([tweet.date,tweet.id, tweet.content, tweet.user.username, tweet.url]) 
    if i > count:
        break;
# Create a dataframe from the tweets list above 
tweets_df_user = pd.DataFrame(tweets_list_user, columns=['Datetime','Tweet Id', 'Text', 'Username', 'url'])
tweets_df_user.to_csv("APomp_bitcoin_only_Tweets.csv",index=False) # Export to a csv file
print("Scraped data have been exported to the csv file")
# Out:
# Scraping data for user: bitcoin @APompliano
# Scraped data have been exported to the csv file

# %%
##### Bitcoin Price Movement #####

# %%
# I included a graph of the price movement of Ethereum alongside Bitcoin for comparisons purposes
import plotly.graph_objects as go
bitcoin = pd.read_csv("/Users/matthewbuttlerives/Downloads/Bitcoin Historical Data - Investing.com Canada.csv")
Edf = pd.read_excel("/Users/matthewbuttlerives/Desktop/Data Folder/ETH-USD.xlsx")

Bitcoin = bitcoin[::-1]
x = Edf["Date"]
y = Edf["Open"]
Y = Bitcoin["Open"]


fig = go.Figure()

fig.add_trace(go.Scatter(x=x,y=y, name = "Ethereum"))
fig.add_trace(go.Scatter(x=x,y=Y, name = "Bitcoin"))


fig.update_layout(
    title_text="Time series plot of Ethereum Open Price with Bitcoin Open Price",)
### Dates of Interest can be between January 2021 and April 2021
# Out:
# <div>                            <div id="3c0af6f0-81f6-4dea-959c-308058e4b681" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c0af6f0-81f6-4dea-959c-308058e4b681")) {                    Plotly.newPlot(                        "3c0af6f0-81f6-4dea-959c-308058e4b681",                        [{"name":"Ethereum","x":["2015-08-07","2015-08-08","2015-08-09","2015-08-10","2015-08-11","2015-08-12","2015-08-13","2015-08-14","2015-08-15","2015-08-16","2015-08-17","2015-08-18","2015-08-19","2015-08-20","2015-08-21","2015-08-22","2015-08-23","2015-08-24","2015-08-25","2015-08-26","2015-08-27","2015-08-28","2015-08-29","2015-08-30","2015-08-31","2015-09-01","2015-09-02","2015-09-03","2015-09-04","2015-09-05","2015-09-06","2015-09-07","2015-09-08","2015-09-09","
# ...

# %%
##### Pre-Processing the Data #####

# %%
mmdf = pd.read_csv('MMCrypto_Bitcoin_tweets_users.csv', names = ['Datetime','Tweet Id','Text', 'Username', 'url'])
rvdf = pd.read_csv('Roger_Ver_bitcoin_only_tweets_users.csv', names = ['Datetime','Tweet Id','Text', 'Username', 'url'])
aadf = pd.read_csv('Aantop_bitcoin_only_tweets_users.csv', names = ['Datetime','Tweet Id','Text', 'Username', 'url'])
tddf = pd.read_csv('TimDraper_bitcoin_only_tweets_users.csv', names = ['Datetime','Tweet Id','Text', 'Username', 'url'])
apdf = pd.read_csv('APomp_bitcoin_only_Tweets.csv', names = ['Datetime','Tweet Id','Text', 'Username', 'url'])

# %%
#### Text Pre-processing ####

# %%
##### 1: Remove Punctuations
# Defining the function to remove punctuation
def remove_punctuation(text):
    punctuationfree="".join([i for i in text if i not in string.punctuation])
    return punctuationfree

# Storing the puntuation free text
mmdf['punctuation_free']= mmdf['Text'].apply(lambda x:remove_punctuation(x))
rvdf['punctuation_free']= rvdf['Text'].apply(lambda x:remove_punctuation(x))
aadf['punctuation_free']= aadf['Text'].apply(lambda x:remove_punctuation(x))
tddf['punctuation_free']= tddf['Text'].apply(lambda x:remove_punctuation(x))
apdf['punctuation_free']= apdf['Text'].apply(lambda x:remove_punctuation(x))

# %%
##### 2: Lowering Text
mmdf['msg_lower']= mmdf['punctuation_free'].apply(lambda x: x.lower())
rvdf['msg_lower']= rvdf['punctuation_free'].apply(lambda x: x.lower())
aadf['msg_lower']= aadf['punctuation_free'].apply(lambda x: x.lower())
tddf['msg_lower']= tddf['punctuation_free'].apply(lambda x: x.lower())
apdf['msg_lower']= apdf['punctuation_free'].apply(lambda x: x.lower())


##### 3: Tokenization
mmdf['msg_tokenized']= mmdf['msg_lower'].apply(lambda x: word_tokenize(x))
rvdf['msg_tokenized']= rvdf['msg_lower'].apply(lambda x: word_tokenize(x))
aadf['msg_tokenized']= aadf['msg_lower'].apply(lambda x: word_tokenize(x))
tddf['msg_tokenized']= tddf['msg_lower'].apply(lambda x: word_tokenize(x))
apdf['msg_tokenized']= apdf['msg_lower'].apply(lambda x: word_tokenize(x))

# %%
# Stop words present in the library
import nltk
stopwords = nltk.corpus.stopwords.words('english')

# Defining the function to remove stopwords from tokenized text
def remove_stopwords(text):
    output= [i for i in text if i not in stopwords]
    return output

# Applying the function
mmdf['no_stopwords']= mmdf['msg_tokenized'].apply(lambda x:remove_stopwords(x))
rvdf['no_stopwords']= rvdf['msg_tokenized'].apply(lambda x:remove_stopwords(x))
aadf['no_stopwords']= aadf['msg_tokenized'].apply(lambda x:remove_stopwords(x))
tddf['no_stopwords']= tddf['msg_tokenized'].apply(lambda x:remove_stopwords(x))
apdf['no_stopwords']= apdf['msg_tokenized'].apply(lambda x:remove_stopwords(x))

##### 5: Lemmatization 
# Defining the object for Lemmatization
wordnet_lemmatizer = WordNetLemmatizer()


# Defining the function for lemmatization
def lemmatizer(text):
    lemm_text = [wordnet_lemmatizer.lemmatize(word) for word in text]
    return lemm_text

mmdf['msg_lemmatized']=mmdf['no_stopwords'].apply(lambda x:lemmatizer(x))
rvdf['msg_lemmatized']=rvdf['no_stopwords'].apply(lambda x:lemmatizer(x))
aadf['msg_lemmatized']=aadf['no_stopwords'].apply(lambda x:lemmatizer(x))
tddf['msg_lemmatized']=tddf['no_stopwords'].apply(lambda x:lemmatizer(x))
apdf['msg_lemmatized']=apdf['no_stopwords'].apply(lambda x:lemmatizer(x))

clean_posts_mmdf = mmdf.msg_lemmatized
keywords_mmdf = mmdf.msg_lemmatized.copy()
clean_posts_rvdf = rvdf.msg_lemmatized
keywords_rvdf = rvdf.msg_lemmatized.copy()
clean_posts_aadf = aadf.msg_lemmatized
keywords_aadf = aadf.msg_lemmatized.copy()
clean_posts_tddf = tddf.msg_lemmatized
keywords_tddf = tddf.msg_lemmatized.copy()
clean_posts_apdf = apdf.msg_lemmatized
keywords_apdf = apdf.msg_lemmatized.copy()

# %%
keywords_mmdf.head(100)
# Out:
# 0                                                [text]
# 1     [bitcoin, conference, found, monster, pattern,...
# 2     [wreversal, bitcoin, attempt, httpstcobngtnn3eav]
# 3     [star, war, bitcoin, pattern, httpstco0d9u5y69i5]
# 4     [woooow, bitcoin, broke, already, 😂, httpstco4...
#                             ...
# 95    [soon, people, measure, usd, bitcoin, 1, usd, ...
# 96    [bitcoin, knock, knock, knocking, 60k, ‘, dooo...
# 97    [bitcoin, broke, predicted, last, video, https...
# 98    [bitcoin, broke, alltime, high, exactly, predi...
# 99                     [scared, click, bitcoin, update]
# Name: msg_lemmatized, Length: 100, dtype: object

# %%
##### 6: Frequency Distribution

from nltk.probability import FreqDist

# %%
coins = pd.read_csv("/Users/matthewbuttlerives/Desktop/Data Folder/coins.csv",names=['coin','ticker'])

# %%
# Cleaning the coins and tickers from periods, comas, and dashes
coins['coin'] = coins['coin'].str.lower()
coins['coin'] = coins['coin'].str.replace(" ","")
coins['coin'] = coins['coin'].str.replace(".","")
coins['coin'] = coins['coin'].str.replace(",","")
coins['coin'] = coins['coin'].str.replace(".","")
coins['coin'] = coins['coin'].str.replace("-","")
coins['ticker'] = coins['ticker'].str.replace(".","")
coins['ticker'] = coins['ticker'].str.replace(",","")
# Out:
# /var/folders/dq/3qj0hnk53pb8rjp2l_k7zby80000gn/T/ipykernel_12374/164868825.py:4: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#
# /var/folders/dq/3qj0hnk53pb8rjp2l_k7zby80000gn/T/ipykernel_12374/164868825.py:6: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#
# /var/folders/dq/3qj0hnk53pb8rjp2l_k7zby80000gn/T/ipykernel_12374/164868825.py:8: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.

# %%
# Generating list of tickers
ticker_list = coins['ticker'].tolist()
ticker_list = list(dict.fromkeys(ticker_list))

# %%
# Generating list of coins
coin_list = coins['coin'].tolist()
coin_list = list(dict.fromkeys(coin_list))

# %%
#generating check list to delete all tokens not related to coins/tickers
check_list = []
check_list.extend(ticker_list)
check_list.extend(coin_list)

# %%
#empty list to contain all the words
words = []

# %%
# clean_posts_mmdf = mmdf.msg_lemmatized
# clean_posts_rvdf = rvdf.msg_lemmatized
# clean_posts_aadf = aadf.msg_lemmatized
# clean_posts_tddf = tddf.msg_lemmatized
# clean_posts_apdf = apdf.msg_lemmatized

#deleting all tokens not related to coins/tickers, finding and replacing tickers to coins
for i in range(len(clean_posts_mmdf)):
    clean_posts_mmdf[i] = [j for j in clean_posts_mmdf[i] if j in check_list]
    for k in range(len(coins)):
        clean_posts_mmdf[i] = [coins.iloc[k,0] if l == coins.iloc[k,1] else l for l in clean_posts_mmdf[i]]
        clean_posts_mmdf[i] = list(dict.fromkeys(clean_posts_mmdf[i]))
    words.extend(clean_posts_mmdf[i])
    
#deleting all tokens not related to coins/tickers, finding and replacing tickers to coins
for i in range(len(clean_posts_rvdf)):
    clean_posts_rvdf[i] = [j for j in clean_posts_rvdf[i] if j in check_list]
    for k in range(len(coins)):
        clean_posts_rvdf[i] = [coins.iloc[k,0] if l == coins.iloc[k,1] else l for l in clean_posts_rvdf[i]]
        clean_posts_rvdf[i] = list(dict.fromkeys(clean_posts_rvdf[i]))
    words.extend(clean_posts_rvdf[i])
    
for i in range(len(clean_posts_aadf)):
    clean_posts_aadf[i] = [j for j in clean_posts_aadf[i] if j in check_list]
    for k in range(len(coins)):
        clean_posts_aadf[i] = [coins.iloc[k,0] if l == coins.iloc[k,1] else l for l in clean_posts_aadf[i]]
        clean_posts_aadf[i] = list(dict.fromkeys(clean_posts_aadf[i]))
    words.extend(clean_posts_aadf[i])
    
for i in range(len(clean_posts_tddf)):
    clean_posts_tddf[i] = [j for j in clean_posts_tddf[i] if j in check_list]
    for k in range(len(coins)):
        clean_posts_tddf[i] = [coins.iloc[k,0] if l == coins.iloc[k,1] else l for l in clean_posts_tddf[i]]
        clean_posts_tddf[i] = list(dict.fromkeys(clean_posts_tddf[i]))
    words.extend(clean_posts_tddf[i])
    
for i in range(len(clean_posts_apdf)):
    clean_posts_apdf[i] = [j for j in clean_posts_apdf[i] if j in check_list]
    for k in range(len(coins)):
        clean_posts_apdf[i] = [coins.iloc[k,0] if l == coins.iloc[k,1] else l for l in clean_posts_apdf[i]]
        clean_posts_apdf[i] = list(dict.fromkeys(clean_posts_apdf[i]))
    words.extend(clean_posts_apdf[i])

# %%
#defining an object for frequency distribution of words   

fdist = FreqDist(words)

# %%
coin = pd.DataFrame.from_dict(fdist, orient='index')
coin.columns = ['Frequency']
coin.index.name = 'Token'
coin = coin.reset_index()

# %%
#sorting by frequency, descending
coin = coin.sort_values(by=['Frequency'], ascending=False)
#obtaining the top 5 coins
top_5 = coin.head(5)
#generating list of top 5 coins

top_5_coins = top_5['Token'].tolist()
top_5_coins = list(dict.fromkeys(top_5_coins))

# %%
#deleting tokens not in the top 5 coins
for i in range(len(clean_posts_mmdf)):
    clean_posts_mmdf[i] = [j for j in clean_posts_mmdf[i] if j in top_5_coins]
for i in range(len(clean_posts_rvdf)):
    clean_posts_rvdf[i] = [j for j in clean_posts_rvdf[i] if j in top_5_coins]
for i in range(len(clean_posts_aadf)):
    clean_posts_aadf[i] = [j for j in clean_posts_aadf[i] if j in top_5_coins]
for i in range(len(clean_posts_tddf)):
    clean_posts_tddf[i] = [j for j in clean_posts_tddf[i] if j in top_5_coins]
for i in range(len(clean_posts_apdf)):
    clean_posts_apdf[i] = [j for j in clean_posts_apdf[i] if j in top_5_coins]

# %%
#deleting rows with empty list
top_coins_posts_mmdf = list(filter(None, clean_posts_mmdf))     
top_coins_posts_rvdf = list(filter(None, clean_posts_rvdf))  
top_coins_posts_aadf = list(filter(None, clean_posts_aadf))   
top_coins_posts_tddf = list(filter(None, clean_posts_tddf))    
top_coins_posts_apdf = list(filter(None, clean_posts_apdf))

# %%
import itertools

# %%
#getting all combinations of pairs
all_pairs = list(itertools.product(top_5_coins, repeat=2))

# %%
#counting the number of cooccurences of each pair
cooccurence_mmdf = {pair: len([x for x in top_coins_posts_mmdf if set(pair) <= set(x)]) for pair in all_pairs}
cooccurence_rvdf = {pair: len([x for x in top_coins_posts_rvdf if set(pair) <= set(x)]) for pair in all_pairs}
cooccurence_aadf = {pair: len([x for x in top_coins_posts_aadf if set(pair) <= set(x)]) for pair in all_pairs}
cooccurence_tddf = {pair: len([x for x in top_coins_posts_tddf if set(pair) <= set(x)]) for pair in all_pairs}
cooccurence_apdf = {pair: len([x for x in top_coins_posts_apdf if set(pair) <= set(x)]) for pair in all_pairs}

#creating an empty dataframe to contain tokens used in conjunction with each coin
keywords_count = pd.DataFrame(columns=['Token','Word_List'])
for i in range(len(top_5_coins)):
    keywords_count = keywords_count.append({'Token':top_5_coins[i],
                                            'Word_List':[top_5_coins[i],]},
                                           ignore_index=True)

# %%
# creating an empty list to contain tokens used for all cars
all_tokens = []

#assigning tokens to coins it mentioned together with and creating a list of tokens in every posts
for i in range(len(keywords_mmdf)):
    for j in range(len(top_5_coins)):
        if top_5_coins[j] in keywords_mmdf[i]:
            keywords_count.iloc[j,1] += list(dict.fromkeys(keywords_mmdf[i]))
    all_tokens.extend(list(dict.fromkeys(keywords_mmdf[i])))

#assigning tokens to coins it mentioned together with and creating a list of tokens in every posts
for i in range(len(keywords_rvdf)):
    for j in range(len(top_5_coins)):
        if top_5_coins[j] in keywords_rvdf[i]:
            keywords_count.iloc[j,1] += list(dict.fromkeys(keywords_rvdf[i]))
    all_tokens.extend(list(dict.fromkeys(keywords_rvdf[i])))
    
for i in range(len(keywords_aadf)):
    for j in range(len(top_5_coins)):
        if top_5_coins[j] in keywords_aadf[i]:
            keywords_count.iloc[j,1] += list(dict.fromkeys(keywords_aadf[i]))
    all_tokens.extend(list(dict.fromkeys(keywords_aadf[i])))
for i in range(len(keywords_tddf)):
    for j in range(len(top_5_coins)):
        if top_5_coins[j] in keywords_tddf[i]:
            keywords_count.iloc[j,1] += list(dict.fromkeys(keywords_tddf[i]))
    all_tokens.extend(list(dict.fromkeys(keywords_tddf[i])))
for i in range(len(keywords_apdf)):
    for j in range(len(top_5_coins)):
        if top_5_coins[j] in keywords_apdf[i]:
            keywords_count.iloc[j,1] += list(dict.fromkeys(keywords_apdf[i]))
    all_tokens.extend(list(dict.fromkeys(keywords_apdf[i])))

# %%
#finding the frequency of each token, turning it into a dataframe and exporting it
keyword_all = FreqDist(all_tokens)
keyword_all = keyword_all.most_common(100)
df_keyword_all = pd.DataFrame(keyword_all)
df_keyword_all.to_csv('keywords_bitcoin_all.csv', index=False)

# %%
#finding the frequency of each token mentioned along each coin, turning it into a dataframe and exporting it     
for i in range(len(top_5_coins)):
    keywords_count.iloc[i,1] = [k for k in keywords_count.iloc[i,1] if k not in check_list]
    globals()['keyword_'+top_5_coins[i]] = FreqDist(keywords_count.iloc[i,1])
    globals()['keyword_'+top_5_coins[i]]  = globals()['keyword_'+top_5_coins[i]].most_common(25)
    globals()['df_keyword_'+top_5_coins[i]] = pd.DataFrame(globals()['keyword_'+top_5_coins[i]])
    globals()['df_keyword_'+top_5_coins[i]].to_csv('keyword_bitcoin'+top_5_coins[i]+'.csv', index=False)

# %%
#aggregating coin_association frequency
# coin_association_mmdf = pd.DataFrame.from_dict(cooccurence_mmdf, orient='index', columns=['Joint_freq'])
# coin_association_rvdf = pd.DataFrame.from_dict(cooccurence_rvdf, orient='index', columns=['Joint_freq'])
# coin_association_aadf = pd.DataFrame.from_dict(cooccurence_aadf, orient='index', columns=['Joint_freq'])
# coin_association_tddf = pd.DataFrame.from_dict(cooccurence_tddf, orient='index', columns=['Joint_freq'])
# coin_association_apdf = pd.DataFrame.from_dict(cooccurence_apdf, orient='index', columns=['Joint_freq'])

# %%
all_tokens
# Out:
# ['text',
#  'bitcoin',
#  'conference',
#  'found',
#  'monster',
#  'pattern',
#  'break',
#  'second',
#  'press',
#  '🧡',
#  'imminent',
#  'video',
#  'wreversal',
#  'bitcoin',
#  'attempt',
#  'httpstcobngtnn3eav',
#  'star',
#  'war',
#  'bitcoin',
#  'pattern',
#  'httpstco0d9u5y69i5',
#  'woooow',
#  'bitcoin',
#  'broke',
#  'already',
#  '😂',
#  'httpstco4bsqtknk2l',
#  'bullish',
#  '28',
#  '‘',
#  '000',
#  'merchant',
#  'added',
#  'bitcoin',
#  'payment',
#  'method',
#  'thanks',
#  'paypal',
#  'bitcoin',
#  'satoshi',
#  'millionaire',
#  '590',
#  'bullish',
#  'bitcoin',
#  'news',
#  'ever',
#  'httpstco4onkfmkvj8',
#  'update',
#  'bitcoin',
#  'trade',
#  'pumped',
#  'yesterday',
#  'twitter',
#  'httpstcojgy4p4wejx',
#  'huge',
#  'bitcoin',
#  'trade',
#  'announcement',
#  '’',
#  'crazy',
#  'press',
#  '🧡',
#  'imminent',
#  'short',
#  'video',
#  'congratulation',
#  'hold',
#  '01',
#  'bitcoin',
#  'youll',
#  'millionaire',
#  'bitcoin',
# ...

# %%
bitcoin_keywords = pd.read_csv("/Users/matthewbuttlerives/Desktop/Data Folder/keyword_bitcoinbitcoin.csv")

# %%
bitcoin_keywords
# Out:
#            0    1
# 0          ’  191
# 1        amp  147
# 2      video  109
# 3          🧡  103
# 4        one   88
# 5        new   86
# 6      world   84
# 7      press   82
# 8          ‘   82
# 9       want   79
# 10    people   78
# 11     learn   75
# 12      year   74
# 13    market   72
# 14      last   66
# 15       buy   66
# 16     going   65
# 17      time   63
# 18         1   58
# 19     today   57
# 20     every   57
# 21         0   56
# 22      live   54
# 23  investor   53
# 24      like   51
